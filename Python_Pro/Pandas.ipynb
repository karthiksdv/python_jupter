# %% [markdown]
# This is some text

# %%
32*42
# Out:
# 1344

# %%
import pandas

# %%
pandas.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit: None
# python: 3.7.1.final.0
# python-bits: 64
# OS: Darwin
# OS-release: 17.7.0
# machine: x86_64
# processor: i386
# byteorder: little
# LC_ALL: en_US.UTF-8
# LANG: en_US.UTF-8
# LOCALE: en_US.UTF-8
#
# pandas: 0.24.2
# pytest: 4.0.2
# pip: 21.2.4
# setuptools: 53.0.0
# Cython: 0.29.2
# numpy: 1.18.0
# scipy: 1.3.1
# pyarrow: None
# xarray: None
# IPython: 7.13.0
# sphinx: 1.8.2
# patsy: 0.5.1
# dateutil: 2.7.5
# pytz: 2018.7
# blosc: None
# bottleneck: 1.2.1
# tables: 3.4.4
# numexpr: 2.6.8
# feather: None
# matplotlib: 3.0.2
# openpyxl: 2.5.12
# xlrd: 1.2.0
# xlwt: 1.3.0
# xlsxwriter: 1.1.2
# lxml.etree: 4.2.5
# bs4: 4.6.3
# html5lib: 1.0.1
# sqlalchemy: 1.2.15
# pymysql: 0.9.3
# psycopg2: None
# jinja2: 2.10
# s3fs: None
# fastparquet: 0.3.1
# pandas_gbq: None
# pandas_datareader: None
# gcsfs: None

# %%
import pandas as pd
pd.__version__
# Out:
# '0.24.2'

# %%
import pandas as pd

# %%
## Reading the CSV file and understand it. it will make more senseof these two lines of code in the read_csv() video
#oo = pd.read_csv('/Users/devuser/Python_Pro/data/olypics.csv', skiprows=4)

oo = pd.read_csv('/Users/devuser/Python_Pro/data/olympics.csv',encoding="ISO-8859-1", skiprows=4)
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo
# Out:
#           City  Edition      Sport       Discipline  \
# 0       Athens     1896   Aquatics         Swimming
# 1       Athens     1896   Aquatics         Swimming
# 2       Athens     1896   Aquatics         Swimming
# 3       Athens     1896   Aquatics         Swimming
# 4       Athens     1896   Aquatics         Swimming
# 5       Athens     1896   Aquatics         Swimming
# 6       Athens     1896   Aquatics         Swimming
# 7       Athens     1896   Aquatics         Swimming
# 8       Athens     1896   Aquatics         Swimming
# 9       Athens     1896   Aquatics         Swimming
# 10      Athens     1896   Aquatics         Swimming
# 11      Athens     1896  Athletics        Athletics
# 12      Athens     1896  Athletics        Athletics
# 13      Athens     1896  Athletics        Athletics
# 14      Athens     1896  Athletics        Athletics
# 15      Athens     1896  Athletics        Athletics
# 16      Athens     1896  Athletics        Athletics
# ...

# %%
oo.City
# Out:
# 0         Athens
# 1         Athens
# 2         Athens
# 3         Athens
# 4         Athens
# 5         Athens
# 6         Athens
# 7         Athens
# 8         Athens
# 9         Athens
# 10        Athens
# 11        Athens
# 12        Athens
# 13        Athens
# 14        Athens
# 15        Athens
# 16        Athens
# 17        Athens
# 18        Athens
# 19        Athens
# 20        Athens
# 21        Athens
# 22        Athens
# 23        Athens
# 24        Athens
# 25        Athens
# 26        Athens
# 27        Athens
# 28        Athens
# 29        Athens
#           ...
# 29186    Beijing
# 29187    Beijing
# 29188    Beijing
# 29189    Beijing
# 29190    Beijing
# 29191    Beijing
# 29192    Beijing
# 29193    Beijing
# 29194    Beijing
# 29195    Beijing
# 29196    Beijing
# 29197    Beijing
# 29198    Beijing
# 29199    Beijing
# 29200    Beijing
# 29201    Beijing
# 29202    Beijing
# 29203    Beijing
# 29204    Beijing
# 29205    Beijing
# 29206    Beijing
# ...

# %%
oo['City'].head()
# Out:
# 0    Athens
# 1    Athens
# 2    Athens
# 3    Athens
# 4    Athens
# Name: City, dtype: object

# %%
oo[['Edition','Sport','Athlete']].head()
# Out:
#    Edition     Sport             Athlete
# 0     1896  Aquatics       HAJOS, Alfred
# 1     1896  Aquatics    HERSCHMANN, Otto
# 2     1896  Aquatics   DRIVAS, Dimitrios
# 3     1896  Aquatics  MALOKINIS, Ioannis
# 4     1896  Aquatics  CHASAPIS, Spiridon

# %%
# 1 List our Olympics DataFrame
oo
## 2 List only the NOC column both bracket and dot notation. What type is this object?
#oo.NOC
oo['NOC']
type(oo.NOC)
type(oo['NOC'])

# 3 List the Edition, City, Athlete Name and Medal Columns. What type is this object?

oo[['Edition','City','Athlete','Medal']].head(10)
# Out:
#    Edition    City                Athlete   Medal
# 0     1896  Athens          HAJOS, Alfred    Gold
# 1     1896  Athens       HERSCHMANN, Otto  Silver
# 2     1896  Athens      DRIVAS, Dimitrios  Bronze
# 3     1896  Athens     MALOKINIS, Ioannis    Gold
# 4     1896  Athens     CHASAPIS, Spiridon  Silver
# 5     1896  Athens  CHOROPHAS, Efstathios  Bronze
# 6     1896  Athens          HAJOS, Alfred    Gold
# 7     1896  Athens       ANDREOU, Joannis  Silver
# 8     1896  Athens  CHOROPHAS, Efstathios  Bronze
# 9     1896  Athens          NEUMANN, Paul    Gold

# %%
type(oo[['Edition','City','Athlete','Medal']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # OVER VIEW OF SHAPE AND VALIDATION

# %%
oo.shape
# Out:
# (29216, 10)

# %%
oo.shape[0]
# Out:
# 29216

# %%
oo.describe()
# Out:
#             Edition
# count  29216.000000
# mean    1967.713171
# std       32.406293
# min     1896.000000
# 25%     1948.000000
# 50%     1976.000000
# 75%     1996.000000
# max     2008.000000

# %%
type(oo[['Edition','City','Athlete','Medal']])
# Out:
# pandas.core.frame.DataFrame

# %%
oo.select_dtypes(include=object).columns
# Out:
# Index(['City', 'Sport', 'Discipline', 'Athlete', 'NOC', 'Gender', 'Event',
#        'Event_gender', 'Medal'],
#       dtype='object')

# %% [markdown]
# # BASIC ANALYSIS

# %% [markdown]
# # Value Counts

# %%
oo.Edition.value_counts(ascending=True)
# Out:
# 1896     151
# 1904     470
# 1900     512
# 1932     615
# 1928     710
# 1908     804
# 1948     814
# 1936     875
# 1960     882
# 1924     884
# 1956     885
# 1912     885
# 1952     889
# 1964    1010
# 1968    1031
# 1972    1185
# 1920    1298
# 1976    1305
# 1980    1387
# 1984    1459
# 1988    1546
# 1992    1705
# 1996    1859
# 2004    1998
# 2000    2015
# 2008    2042
# Name: Edition, dtype: int64

# %%
oo.Gender.value_counts()
# Out:
# Men      21721
# Women     7495
# Name: Gender, dtype: int64

# %%
oo.Gender.value_counts(ascending=True,dropna = False)
# Out:
# Women     7495
# Men      21721
# Name: Gender, dtype: int64

# %%
oo.City.sort_values()
# Out:
# 5177     Amsterdam
# 5398     Amsterdam
# 5399     Amsterdam
# 5400     Amsterdam
# 5401     Amsterdam
# 5402     Amsterdam
# 5403     Amsterdam
# 5397     Amsterdam
# 5404     Amsterdam
# 5406     Amsterdam
# 5407     Amsterdam
# 5408     Amsterdam
# 5409     Amsterdam
# 5410     Amsterdam
# 5411     Amsterdam
# 5405     Amsterdam
# 5396     Amsterdam
# 5395     Amsterdam
# 5394     Amsterdam
# 5379     Amsterdam
# 5380     Amsterdam
# 5381     Amsterdam
# 5382     Amsterdam
# 5383     Amsterdam
# 5384     Amsterdam
# 5385     Amsterdam
# 5386     Amsterdam
# 5387     Amsterdam
# 5388     Amsterdam
# 5389     Amsterdam
#            ...
# 10762        Tokyo
# 10761        Tokyo
# 10760        Tokyo
# 10759        Tokyo
# 10758        Tokyo
# 10757        Tokyo
# 10756        Tokyo
# 10755        Tokyo
# 10754        Tokyo
# 10753        Tokyo
# 10752        Tokyo
# 10751        Tokyo
# 10750        Tokyo
# 10733        Tokyo
# 10749        Tokyo
# 10747        Tokyo
# ...

# %%
oo.sort_values(by=['Edition','Athlete'])
# Out:
#           City  Edition          Sport       Discipline  \
# 7       Athens     1896       Aquatics         Swimming
# 82      Athens     1896     Gymnastics      Artistic G.
# 110     Athens     1896     Gymnastics      Artistic G.
# 111     Athens     1896     Gymnastics      Artistic G.
# 48      Athens     1896        Cycling     Cycling Road
# 19      Athens     1896      Athletics        Athletics
# 134     Athens     1896         Tennis           Tennis
# 140     Athens     1896         Tennis           Tennis
# 13      Athens     1896      Athletics        Athletics
# 21      Athens     1896      Athletics        Athletics
# 84      Athens     1896     Gymnastics      Artistic G.
# 99      Athens     1896     Gymnastics      Artistic G.
# 66      Athens     1896        Fencing          Fencing
# 4       Athens     1896       Aquatics         Swimming
# 5       Athens     1896       Aquatics         Swimming
# 8       Athens     1896       Aquatics         Swimming
# ...

# %%
oo[(oo.Medal == 'Gold') & (oo.Gender == 'Women')]
# Out:
#             City  Edition          Sport       Discipline  \
# 417        Paris     1900           Golf             Golf
# 641        Paris     1900         Tennis           Tennis
# 649        Paris     1900         Tennis           Tennis
# 710     St Louis     1904        Archery          Archery
# 713     St Louis     1904        Archery          Archery
# 730     St Louis     1904        Archery          Archery
# 731     St Louis     1904        Archery          Archery
# 732     St Louis     1904        Archery          Archery
# 733     St Louis     1904        Archery          Archery
# 1185      London     1908        Archery          Archery
# 1843      London     1908        Skating   Figure skating
# 1849      London     1908        Skating   Figure skating
# 1870      London     1908         Tennis           Tennis
# 1876      London     1908         Tennis           Tennis
# 1941   Stockholm     1912       Aquatics           Diving
# ...

# %%
oo[(oo.Medal == 'Gold') & (oo.NOC == 'IND') & (oo.Event != 'hockey')]
# Out:
#           City  Edition     Sport Discipline          Athlete  NOC Gender  \
# 28856  Beijing     2008  Shooting   Shooting  BINDRA, Abhinav  IND    Men
#
#                           Event Event_gender Medal
# 28856  10m air rifle (60 shots)            M  Gold

# %%
oo[oo.Athlete.str.contains('Jon')]
# Out:
#                         City  Edition          Sport       Discipline  \
# 3086                 Antwerp     1920      Athletics        Athletics
# 4337                   Paris     1924      Athletics        Athletics
# 6690                  Berlin     1936     Equestrian         Eventing
# 7949                  London     1948       Shooting         Shooting
# 8784                Helsinki     1952        Sailing          Sailing
# 8929   Melbourne / Stockholm     1956       Aquatics         Swimming
# 8969   Melbourne / Stockholm     1956       Aquatics         Swimming
# 9679   Melbourne / Stockholm     1956        Sailing          Sailing
# 9820                    Rome     1960       Aquatics         Swimming
# 9831                    Rome     1960       Aquatics         Swimming
# 9875                    Rome     1960       Aquatics         Swimming
# 10062                   Rome     1960     Basketball       Basketball
# ...

# %% [markdown]
# Challenge

# %%
# 1. Which events did Jesse Ownens wind medal?
#oo.head(3)
oo[oo.Athlete.str.contains('OWENS, Jesse')]
# Out:
#         City  Edition      Sport Discipline       Athlete  NOC Gender  \
# 6427  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6439  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6456  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6523  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
#
#              Event Event_gender Medal
# 6427          100m            M  Gold
# 6439          200m            M  Gold
# 6456  4x100m relay            M  Gold
# 6523     long jump            M  Gold

# %%
jo =oo[oo.Athlete.str.contains('Jesse') & oo.Athlete.str.contains('OWENS')]
jo.Event.value_counts()
# Out:
# 4x100m relay    1
# long jump       1
# 200m            1
# 100m            1
# Name: Event, dtype: int64

# %%
# 2 Which country has won the most gold medals in singles badminton over the years?

raw_data = oo[(oo.Sport=='Badminton') & (oo.Gender == 'Men') & (oo.Medal == 'Gold') ]
raw_data.NOC.value_counts()
#raw_data.Athlete.sort_values()
#raw_data.Athlete.sort_values()
#sorted = raw_data.sort_values(by=['Athlete'])
#sorted
#sorted.NOC.value_counts()
#raw_data.sort_values(by='Athlete')
# Out:
# INA    8
# KOR    6
# CHN    4
# DEN    1
# Name: NOC, dtype: int64

# %%
sorted = raw_data.sort_values(by=['Athlete'])
sorted
# Out:
#             City  Edition      Sport Discipline                  Athlete  NOC  \
# 20045  Barcelona     1992  Badminton  Badminton        BUDI KUSUMA, Alan  INA
# 23701     Sydney     2000  Badminton  Badminton            GUNAWAN, Tony  INA
# 25718     Athens     2004  Badminton  Badminton             HA, Tae-Kwon  KOR
# 25734     Athens     2004  Badminton  Badminton          HIDAYAT, Taufik  INA
# 21787    Atlanta     1996  Badminton  Badminton  HOYER-LARSEN, Poul Erik  DEN
# 23717     Sydney     2000  Badminton  Badminton              JI, Xinpeng  CHN
# 27725    Beijing     2008  Badminton  Badminton             KIDO, Markis  INA
# 25719     Athens     2004  Badminton  Badminton           KIM, Dong Moon  KOR
# 21773    Atlanta     1996  Badminton  Badminton           KIM, Dong Moon  KOR
# 20031  Barcelona     1992  Badminton  Badminton            KIM, Moon-Soo  KOR
# 27727    Beijing     2008  Badminton  Badminton             LEE, Yongdae  KOR
# ...

# %%
# 3. Which 3 countries won most medals in from 1984 to 2008
medals = oo[oo.Edition > 1983]
medals.NOC.value_counts().head(3)
# Out:
# USA    1837
# AUS     762
# GER     691
# Name: NOC, dtype: int64

# %%
# 4 Male gold medal winners in 100m track and field sprint.
    ## list out the most recent years
    ## show Olympic city, edition, athlete and country
    
#oo[oo.Sport.str.contains('Running')]
run = oo[(oo.Event == '100m') & (oo.Medal == 'Gold') & (oo.Gender == 'Men')]
result = run.sort_values(by=['Edition'], ascending=False)[['City','Edition','Athlete','NOC']].head(5)
result
#result[['City','Edition','Athlete','NOC']]
# Out:
#             City  Edition            Athlete  NOC
# 27552    Beijing     2008        BOLT, Usain  JAM
# 25539     Athens     2004     GATLIN, Justin  USA
# 23521     Sydney     2000    GREENE, Maurice  USA
# 21598    Atlanta     1996    BAILEY, Donovan  CAN
# 19859  Barcelona     1992  CHRISTIE, Linford  GBR

# %%
oo.Athlete.value_counts().head(4)
#oo[oo.Athlete == 'LATYNINA, Larisa']
# Out:
# LATYNINA, Larisa      18
# PHELPS, Michael       16
# ANDRIANOV, Nikolay    15
# SHAKHLIN, Boris       13
# Name: Athlete, dtype: int64

# %% [markdown]
# # Basic Plotting

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Plot Types

# %%
oo.groupby('Edition').plot(kind='bar')
# Out:
# Edition
# 1896    AxesSubplot(0.125,0.125;0.775x0.755)
# 1900    AxesSubplot(0.125,0.125;0.775x0.755)
# 1904    AxesSubplot(0.125,0.125;0.775x0.755)
# 1908    AxesSubplot(0.125,0.125;0.775x0.755)
# 1912    AxesSubplot(0.125,0.125;0.775x0.755)
# 1920    AxesSubplot(0.125,0.125;0.775x0.755)
# 1924    AxesSubplot(0.125,0.125;0.775x0.755)
# 1928    AxesSubplot(0.125,0.125;0.775x0.755)
# 1932    AxesSubplot(0.125,0.125;0.775x0.755)
# 1936    AxesSubplot(0.125,0.125;0.775x0.755)
# 1948    AxesSubplot(0.125,0.125;0.775x0.755)
# 1952    AxesSubplot(0.125,0.125;0.775x0.755)
# 1956    AxesSubplot(0.125,0.125;0.775x0.755)
# 1960    AxesSubplot(0.125,0.125;0.775x0.755)
# 1964    AxesSubplot(0.125,0.125;0.775x0.755)
# 1968    AxesSubplot(0.125,0.125;0.775x0.755)
# 1972    AxesSubplot(0.125,0.125;0.775x0.755)
# 1976    AxesSubplot(0.125,0.125;0.775x0.755)
# 1980    AxesSubplot(0.125,0.125;0.775x0.755)
# 1984    AxesSubplot(0.125,0.125;0.775x0.755)
# 1988    AxesSubplot(0.125,0.125;0.775x0.755)
# ...

# %%
fo = oo[oo.Edition == 1896]

# %%
fo.Sport.value_counts()

# %%
fo.Sport.value_counts().plot(figsize=(10,10));

# %% [markdown]
# # Bar Plot

# %%
fo.Sport.value_counts().plot(kind='bar',color='green',figsize=(10,5));

# %% [markdown]
# # Pie Plot

# %%
fo.Sport.value_counts().plot(kind='pie',figsize=(10,5));

# %% [markdown]
# # Seabon Basic Plotting

# %%
import seaborn as sns

# %%
sns.countplot(x='Medal', data=oo, hue='Gender');

# %% [markdown]
# # Challenge

# %%
# 1. Number of medals by Chinese team in Beijing 2008

# %%
cmt = oo[(oo.Edition == 2008) & (oo.NOC == 'CHN')]
cmt
# Out:
#           City  Edition          Sport       Discipline            Athlete  \
# 27176  Beijing     2008       Aquatics           Diving        ZHOU, Luxin
# 27177  Beijing     2008       Aquatics           Diving          WANG, Xin
# 27178  Beijing     2008       Aquatics           Diving       CHEN, Ruolin
# 27180  Beijing     2008       Aquatics           Diving           QIN, Kai
# 27181  Beijing     2008       Aquatics           Diving          HE, Chong
# 27183  Beijing     2008       Aquatics           Diving         WU, Minxia
# 27184  Beijing     2008       Aquatics           Diving      GUO, Jingjing
# 27188  Beijing     2008       Aquatics           Diving         HUO, Liang
# 27189  Beijing     2008       Aquatics           Diving           LIN, Yue
# 27194  Beijing     2008       Aquatics           Diving       CHEN, Ruolin
# 27195  Beijing     2008       Aquatics           Diving          WANG, Xin
# ...

# %%
cmt.Gender.value_counts().plot(kind='bar');

# %%
sns.countplot(x='Medal',data=cmt, hue='Gender', palette='bwr',order=['Gold','Silver','Bronze'] );

# %%
sns.countplot(x='Medal',data=oo, hue='Gender', palette='coolwarm');

# %%
dk = lambda x,y: x if x > y else y

# %%
print(dk(100,12))
# Out:
# 100

# %%
n = [16,9,4,1]

# %%
print(list(map(lambda x: x**2, n)))
# Out:
# [256, 81, 16, 1]

# %%
print(list(filter(lambda x: x>5, n)))
# Out:
# [16, 9]
