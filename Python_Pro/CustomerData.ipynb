# %%
import pandas as pd
import pandas_profiling as pf

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import seaborn as sns

# %%
data = pd.read_csv("data/CustomerData.csv")
data.head()
# Out:
#    CustomerID  City  NoOfChildren  MinAgeOfChild  MaxAgeOfChild  Tenure  \
# 0        1001     1             2              3              8     210
# 1        1002     1             2              3              6     442
# 2        1003     1             4              3              5     424
# 3        1004     1             1              6              6     261
# 4        1005     1             3              6              9     422
#
#    FrquncyOfPurchase  NoOfUnitsPurchased  FrequencyOFPlay  NoOfGamesPlayed  \
# 0                 11                  11             2344              108
# 1                 20                  20              245               22
# 2                 18                  18             1059              130
# 3                 11                   9              365               34
# 4                 44                  31             1066              102
#
#    NoOfGamesBought FavoriteChannelOfTransaction FavoriteGame  \
# ...

# %%
data.shape
# Out:
# (3209, 14)

# %%
pf.ProfileReport(data)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %%
data.FavoriteGame.value_counts()
# Out:
# Uniform     3053
# Favorite     126
# NONE          30
# Name: FavoriteGame, dtype: int64

# %%
data.FavoriteChannelOfTransaction.value_counts()
# Out:
# Favorite    2637
# Uniform      572
# Name: FavoriteChannelOfTransaction, dtype: int64

# %%
data.City.value_counts()
# Out:
# 1    2843
# 2     366
# Name: City, dtype: int64

# %%
data.FrequencyOFPlay.min()
# Out:
# 0

# %%
for cus_id, details in data.groupby("CustomerID"):
    print(cus_id)
    print(details)
# Out:
# 1001
#    CustomerID  City  NoOfChildren  MinAgeOfChild  MaxAgeOfChild  Tenure  \
# 0        1001     1             2              3              8     210
#
#    FrquncyOfPurchase  NoOfUnitsPurchased  FrequencyOFPlay  NoOfGamesPlayed  \
# 0                 11                  11             2344              108
#
#    NoOfGamesBought FavoriteChannelOfTransaction FavoriteGame  \
# 0               10                      Uniform      Uniform
#
#    TotalRevenueGenerated
# 0                 107.51
# 1002
#    CustomerID  City  NoOfChildren  MinAgeOfChild  MaxAgeOfChild  Tenure  \
# 1        1002     1             2              3              6     442
#
#    FrquncyOfPurchase  NoOfUnitsPurchased  FrequencyOFPlay  NoOfGamesPlayed  \
# 1                 20                  20              245               22
#
#    NoOfGamesBought FavoriteChannelOfTransaction FavoriteGame  \
# 1                7                     Favorite      Uniform
#
#    TotalRevenueGenerated
# ...

# %%
sns.boxplot(data["FrequencyOFPlay"]);

# %%
def mSelection(x):
    return x.fillna(x.mode()[0])

# %%
 data['FavoriteGame'] = data.groupby("CustomerID").FavoriteGame.transform(lambda x : mSelection(x))

# %%
data['FavoriteGame']
# Out:
# 0        Uniform
# 1        Uniform
# 2        Uniform
# 3        Uniform
# 4        Uniform
# 5       Favorite
# 6       Favorite
# 7        Uniform
# 8        Uniform
# 9        Uniform
# 10      Favorite
# 11       Uniform
# 12       Uniform
# 13       Uniform
# 14       Uniform
# 15       Uniform
# 16       Uniform
# 17       Uniform
# 18       Uniform
# 19       Uniform
# 20       Uniform
# 21       Uniform
# 22       Uniform
# 23       Uniform
# 24       Uniform
# 25       Uniform
# 26       Uniform
# 27       Uniform
# 28       Uniform
# 29       Uniform
#           ...
# 3179     Uniform
# 3180     Uniform
# 3181     Uniform
# 3182     Uniform
# 3183     Uniform
# 3184     Uniform
# 3185     Uniform
# 3186     Uniform
# 3187     Uniform
# 3188     Uniform
# 3189     Uniform
# 3190     Uniform
# 3191     Uniform
# 3192     Uniform
# 3193     Uniform
# 3194     Uniform
# 3195     Uniform
# 3196     Uniform
# 3197    Favorite
# 3198     Uniform
# 3199     Uniform
# ...

# %%
pd.get_dummies(data=['FavoriteChannelOfTransaction', 'FavoriteGame'])
# Out:
#    FavoriteChannelOfTransaction  FavoriteGame
# 0                             1             0
# 1                             0             1

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
X = data.drop(columns=["CustomerID","TotalRevenueGenerated"])

# %%
y = data["TotalRevenueGenerated"]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=.3, random_state=0)

# %%
y.head()
# Out:
# 0    107.51
# 1    382.40
# 2    135.01
# 3    125.00
# 4    335.05
# Name: TotalRevenueGenerated, dtype: float64

# %%
# Out:
# 0       107.51
# 1       382.40
# 2       135.01
# 3       125.00
# 4       335.05
# 5       150.00
# 6       127.50
# 7       122.50
# 8       164.96
# 9       112.62
# 10      211.92
# 11      125.04
# 12      167.50
# 13      202.50
# 14      105.50
# 15      117.50
# 16      175.00
# 17      181.71
# 18      144.93
# 19      182.36
# 20      100.00
# 21      199.93
# 22      172.50
# 23      348.09
# 24      185.02
# 25      139.99
# 26      135.00
# 27      388.01
# 28      152.51
# 29      205.01
#          ...
# 3179    151.75
# 3180    125.00
# 3181    222.50
# 3182    240.00
# 3183    461.67
# 3184    147.52
# 3185    300.00
# 3186    118.66
# 3187    231.21
# 3188    105.01
# 3189    188.91
# 3190    205.97
# 3191    107.50
# 3192    100.00
# 3193    110.00
# 3194    115.00
# 3195    117.51
# 3196    172.50
# 3197    222.96
# 3198    115.93
# 3199    249.96
# 3200    175.51
# 3201    117.26
# 3202    261.29
# 3203    205.00
# 3204    132.50
# 3205    223.23
# ...
